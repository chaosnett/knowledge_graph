# %%
import pandas as pd

# %%
pd.read_csv('data/exports/usa/combined_export.csv').head()
# Out:
#   Product Code                                      Product Label  \
# 0           01                                       Live animals
# 1           02                         Meat and edible meat offal
# 2           03  Fish and crustaceans, molluscs and other aquat...
# 3           04  Dairy produce; birds' eggs; natural honey; edi...
# 4           05  Products of animal origin, not elsewhere speci...
#
#    Total Export to China (in USD)  Total Export to Mexico (in USD)  \
# 0                             121                           189179
# 1                               0                          3705598
# 2                           20756                            40359
# 3                            5318                          1869850
# 4                            1003                           208788
#
#    Total Export to India (in USD)  Total Export to Nepal (in USD)  \
# 0                            2695                            1594
# ...

# %%
# Out:
#    Unnamed: 0      0                                                  1  \
# 0           2  TOTAL                                       All products
# 1           3     85  Electrical machinery and equipment and parts t...
# 2           4     84  Nuclear reactors, boilers, machinery and mecha...
# 3           5     95  Toys, games and sports requisites; parts and a...
# 4           6     94  Furniture; bedding, mattresses, mattress suppo...
#
#    Total Import (in USD)
# 0              540073411
# 1              134883233
# 2              115364627
# 3               40333545
# 4               31437833

# %%
# Out:
#         0
# 0   TOTAL
# 1      85
# 2      84
# 3      95
# 4      94
# ..    ...
# 93     04
# 94     02
# 95     41
# 96     51
# 97     47
#
# [98 rows x 1 columns]

# %%
# Out:
#         0                                                  1  \
# 0   TOTAL                                       All products
# 1      85  Electrical machinery and equipment and parts t...
# 2      84  Nuclear reactors, boilers, machinery and mecha...
# 3      95  Toys, games and sports requisites; parts and a...
# 4      94  Furniture; bedding, mattresses, mattress suppo...
# ..    ...                                                ...
# 93     04  Dairy produce; birds' eggs; natural honey; edi...
# 94     02                         Meat and edible meat offal
# 95     41  Raw hides and skins (other than furskins) and ...
# 96     51  Wool, fine or coarse animal hair; horsehair ya...
# 97     47  Pulp of wood or of other fibrous cellulosic ma...
#
#     Total Import (in USD)
# 0               540073411
# 1               134883233
# 2               115364627
# 3                40333545
# 4                31437833
# ..                    ...
# 93                   9177
# ...

# %%
# Out:
#          0                                                  1          2
# 2   'TOTAL                                       All products  540073411
# 3      '85  Electrical machinery and equipment and parts t...  134883233
# 4      '84  Nuclear reactors, boilers, machinery and mecha...  115364627
# 5      '95  Toys, games and sports requisites; parts and a...   40333545
# 6      '94  Furniture; bedding, mattresses, mattress suppo...   31437833
# ..     ...                                                ...        ...
# 95     '04  Dairy produce; birds' eggs; natural honey; edi...       9177
# 96     '02                         Meat and edible meat offal       9334
# 97     '41  Raw hides and skins (other than furskins) and ...       9672
# 98     '51  Wool, fine or coarse animal hair; horsehair ya...       7808
# 99     '47  Pulp of wood or of other fibrous cellulosic ma...       2893
#
# [98 rows x 3 columns]

# %%
# Out:
#        0                                                  1  \
# 2  TOTAL                                       All products
# 3     85  Electrical machinery and equipment and parts t...
# 4     84  Nuclear reactors, boilers, machinery and mecha...
# 5     95  Toys, games and sports requisites; parts and a...
# 6     94  Furniture; bedding, mattresses, mattress suppo...
#
#   Total Import 2023 (in USD)
# 2                  540073411
# 3                  134883233
# 4                  115364627
# 5                   40333545
# 6                   31437833
